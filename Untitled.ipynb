# %%
n = input("Please input a number n = ")
n1 = n + n
n2 = n1 + n
sum = int(n) + int(n1) + int(n2) 
print("the sum is =",sum)
# Out:
# Please input a number n = 5
# the sum is = 615

# %%
SURNAME=input("enter your surnme:")
print("user surname is",SRNAME)
NAME=input("enter your name:")
print("user surname is",NAME)
print("the result is ", str(NAME)+" "+str(SURNAME))

# %%
n=input("input a number n=")
if (n%2)==0 :
    print ( "n is even")
    elif
    print("n i odd")

# %%
str=input("input a string s=")
def odd_values_string(str):
  result = "" 
  for i in range(len(str)):
    if i % 2 == 0:
      result = result + str[i]
  return result

# %%
p=input("input a price p")
if p>=500 :
    p=p*0.5
    elif
    (p>200)and(p<500) :
        p=p*0.7
        elif p<200:
            p=p*0.9
        
print("the price is=",p)
